# %% [markdown]
# <a href="https://colab.research.google.com/github/liliansampaio/BootCamp-Aluna/blob/main/Bootcamp_Datascience_Modulo2_Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **#MÓDULO 1**

# %% [markdown]
# Caderno de exploração dos dados do DataSUS 2008 para frente

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/liliansampaio/Producao_hospitalar_Brasil/main/Dados/A144756189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 12,
                    thousands = ".", decimal = ",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
dengue_pri = pd.read_csv("https://raw.githubusercontent.com/liliansampaio/Producao_hospitalar_Brasil/main/Dados/A055321189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 17,
                    thousands = ".", decimal = ",")
dengue_pri
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          UF de notificação    2007    2008  ...    2012    2013   Total
# 0              11 Rondônia    3128    5644  ...    3194    8485   63573
# 1                  12 Acre     526    2228  ...    2259    2467   80035
# 2              13 Amazonas    1938    7530  ...    5359   17545  103757
# 3               14 Roraima     913    4928  ...    1845     933   20510
# 4                  15 Pará   13958   15620  ...   16327    8941   94155
# 5                 16 Amapá    3631    1207  ...    1533    1683   15783
# 6             17 Tocantins   12820   10349  ...   11795    8698   66107
# 7              21 Maranhão   13345    5510  ...    5270    3489   45617
# ...

# %%
dengue_seg = pd.read_csv("https://raw.githubusercontent.com/liliansampaio/Producao_hospitalar_Brasil/main/Dados/A154006189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 4, sep = ";", skipfooter = 20,
                    thousands = ".", decimal = ",")
dengue_seg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          UF de notificação 2013    2014    2015  ...    2019    2020  2021    Total
# 0              11 Rondônia   20    1994    2250  ...     990    3940     1    19844
# 1                  12 Acre   13   28464    6067  ...   10192    8049    77    64336
# 2              13 Amazonas   30    6318    3662  ...    3986    6195    12    33943
# 3               14 Roraima   10    1128    1110  ...    1605     570     -     5028
# 4                  15 Pará   21    4540    7853  ...    5397    3732     -    44031
# 5                 16 Amapá    1    2181    3400  ...     198      41     -     9366
# 6             17 Tocantins   40    3677    8005  ...   13752    2272     1    43643
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...    2021/Mar          Total
# 22   43 Rio Grande do Sul        -  ... 37798832.80 12764391179.92
# 23  50 Mato Grosso do Sul        -  ...  4035989.77  2324525096.33
# 24         51 Mato Grosso        -  ...  8835890.09  2180119781.15
# 25               52 Goiás        -  ... 24867001.02  4973572261.43
# 26    53 Distrito Federal        -  ... 14731938.43  2592422853.56
#
# [5 rows x 287 columns]

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  ...     2021/Mar          Total
# 0              11 Rondônia         -  ...   4732441.04   996411254.68
# 1                  12 Acre         -  ...   1137341.65   450048530.47
# 2              13 Amazonas         -  ...   6799060.80  1917247936.05
# 3               14 Roraima         -  ...   2381844.31   328876965.09
# 4                  15 Pará         -  ...  13069564.31  4705309002.29
# 5                 16 Amapá         -  ...    989155.40   309860092.59
# 6             17 Tocantins         -  ...    928756.84  1020028272.64
# 7              21 Maranhão         -  ...  17294509.11  3871069498.04
# 8                 22 Piauí         -  ...   9542151.53  2280888802.74
# 9                 23 Ceará         -  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte         -  ...   8733455.36  2660122027.15
# 11              25 Paraíba         -  ...  12517894.05  2614919044.63
# ...

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42500830.29
# 19   180005050.15
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21054991.27
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26641365.101481482

# %%
dados.plot(x = 'Unidade da Federação', y = '2008/Ago')

# %%
dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total por unidade da federação")
plt.show()

# %% [markdown]
# #Desafio 1: Escolher um título mais descritivo, que passe a mensagem adequada.
#
# #Desafio 2: Faça um gráfico para um mês mais recente

# %% [markdown]
# **#Desafio 1: Resolução**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total dos procedimentos hospitalares do SUS por unidade da federação", fontsize = 15)
plt.show()

# %% [markdown]
# **#Desafio 2: Resolução**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2021/Mar', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total dos procedimentos hospitalares do SUS por unidade da federação", fontsize = 15)
plt.show()

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# ...

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374933.66
# 22 Piauí                  17833872.84
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073542.40
# 25 Paraíba                19863848.57
# 26 Pernambuco             71735983.26
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77884805.29
# 31 Minas Gerais          161774658.77
# 32 Espírito Santo         29318260.49
# 33 Rio de Janeiro         83624113.30
# 35 São Paulo             303584114.00
# 41 Paraná                127174381.95
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98566147.88
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
usaveis.loc["12 Acre"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-7ca5d083feed> in <module>()
# ----> 1 usaveis.loc["12 Acre"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
usaveis.plot(figsize=(12,6))

# %%
usaveis.T.head()

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()

# %%
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 2**
#
# #Desafio 1: reposicionar a legenda. Dentro? Fora? Onde?
#
# #Desafio 2: Selecionar 5 estados para plotar

# %% [markdown]
# **#Desafio 1: Reposicionamento da legenda**

# %%
uso = usaveis.T.plot(figsize=(10,6))
uso.legend(loc = 'upper right', fontsize = 5)

# %% [markdown]
# **#Desafio 2: Selecionar 5 estados para plotar**

# %%
estado = usaveis.T[['33 Rio de Janeiro', '25 Paraíba', '13 Amazonas', '35 São Paulo', '41 Paraná']]
estado.plot(figsize=(10,6))

# %%
estado = usaveis.T[['33 Rio de Janeiro', '25 Paraíba', '13 Amazonas', '35 São Paulo', '41 Paraná']]
estado.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 3**

# %%
usaveis.T.columns

# %%
usaveis.T.columns[:5]

# %%
usaveis.index

# %%
usaveis.index[:5]

# %%
usaveis.T[:5]

# %%
usaveis[:5]

# %%
usaveis[:7].T.plot(figsize=(10,6))

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)

# %%
usaveis["total"] = usaveis.sum(axis=1)
usaveis.head()

# %%
ordenado_por_total = usaveis.sort_values("total", ascending = False)
ordenado_por_total.index = ordenado_por_total.index.str[3:]

ordenado_por_total = ordenado_por_total.drop("total", axis=1)
ordenado_por_total.head()

# %%
ordenado_por_total[:5].T.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 3**
#
# #Desafio 1: Escolher uma palete de cores mais adequada com o matplotlib (OK)
# #Desafio 2: Adicionar uma coluna mostrando a região (Norte, Nordeste, Sul, Suldeste e Centro-Oeste) de cada estado (OK)
# #Desafio 3: Formatar o gráfico de custo, deixando ele mais agradável (OK)
# #Desafio 4: Adicione mais um estado aos 05 estados existentes no gráfico e plot (OK)
# #Desafio 5: corte o ponto de maior valor do gráfico (OK)
# #Desafio 5.1: Buscar os casos de dengue no Brasil(época de maior número de casos e regiões mais atingidas) e ver se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de Dengue (OK).
# #Desafio 6: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região (OK).
# #Desafio 7: Adicionar mais um estado novamente e tire suas conclusões sobre estados comparando com os demais. Tire suas conclusões e compartilhe.

# %% [markdown]
# #Desafio 5: Corte o ponto maior valor do gráfico

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# #Desafio 1: Escolher uma palete de cores mais adequada com o matplotlib

# %% [markdown]
# #Desafio 3: Formatar o gráfico de custo, deixando ele mais agradável

# %% [markdown]
# #Desafio 4: Adicione mais um estado aos 05 estados existentes no gráfico e plot

# %%
ordenado_por_total.index

# %%
import matplotlib.pyplot as plt


ax = ordenado_por_total.T[['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Espírito Santo', 'Amazonas', 'Distrito Federal']].plot(cmap = 'plasma', grid = True, figsize = (10,7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# #Desafio 2: Adicionar uma coluna mostrando a região (Norte, Nordeste, Sul, Suldeste e Centro-Oeste) de cada estado

# %%
usaveis

# %%
usaveis.index

# %%
norte = ['Norte']*7
nordeste = ['Nordeste']*9
sudeste = ['Sudeste']*4
sul = ['Sul']*3
centro_oeste = ['Centro-Oeste']*4

regiao = norte + nordeste + sudeste + sul + centro_oeste
regiao

# %%
usaveis_regiao = usaveis
usaveis_regiao.insert(0, 'Regiao', regiao)
usaveis_regiao

# %%
usaveis

# %% [markdown]
# #Desafio 6: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região.

# %%
import matplotlib.pyplot as plt


ax = ordenado_por_total.T[['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Espírito Santo', 'Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# #Desafio 5.1: Buscar os casos de dengue no Brasil(época de maior número de casos e regiões mais atingidas) e ver se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de Dengue.

# %%
dengue1 = dengue_pri.drop("Total", axis = 1)
dengue1 = dengue1.drop("2007", axis = 1)
dengue1 = dengue1.drop("2008", axis = 1)
dengue1

# %%
dengue2 = dengue_seg.drop("Total", axis = 1)
dengue2 = dengue2.drop("UF de notificação", axis = 1)
dengue2 = dengue2.drop("2013", axis = 1)
dengue2 = dengue2.drop("2021", axis = 1)
dengue2

# %%
import pandas as pd

dengue = pd.concat([dengue1, dengue2], axis = 1)

dengue = dengue.set_index("UF de notificação")

dengue

# %%
usaveis_2008 = usaveis[["2008/Jan", "2008/Fev", "2008/Mar", "2008/Abr", "2008/Mai", "2008/Jun", "2008/Jul", "2008/Ago", "2008/Set", "2008/Out", "2008/Nov", "2008/Dez"]]

usaveis_2008["2008"] = usaveis_2008.sum(axis=1)

usaveis_2008 = usaveis_2008[["2008"]]

usaveis_2008.head()

# %%
usaveis_2009 = usaveis[["2009/Jan", "2009/Fev", "2009/Mar", "2009/Abr", "2009/Mai", "2009/Jun", "2009/Jul", "2009/Ago", "2009/Set", "2009/Out", "2009/Nov", "2009/Dez"]]

usaveis_2009["2009"] = usaveis_2009.sum(axis=1)

usaveis_2009 = usaveis_2009[["2009"]]

usaveis_2009.head()

# %%
usaveis_2010 = usaveis[["2010/Jan", "2010/Fev", "2010/Mar", "2010/Abr", "2010/Mai", "2010/Jun", "2010/Jul", "2010/Ago", "2010/Set", "2010/Out", "2010/Nov", "2010/Dez"]]

usaveis_2010["2010"] = usaveis_2010.sum(axis=1)

usaveis_2010 = usaveis_2010[["2010"]]

usaveis_2010.head()

# %%
usaveis_2011 = usaveis[["2011/Jan", "2011/Fev", "2011/Mar", "2011/Abr", "2011/Mai", "2011/Jun", "2011/Jul", "2011/Ago", "2011/Set", "2011/Out", "2011/Nov", "2011/Dez"]]

usaveis_2011["2011"] = usaveis_2011.sum(axis=1)

usaveis_2011 = usaveis_2011[["2011"]]

usaveis_2011.head()

# %%
usaveis_2012 = usaveis[["2012/Jan", "2012/Fev", "2012/Mar", "2012/Abr", "2012/Mai", "2012/Jun", "2012/Jul", "2012/Ago", "2012/Set", "2012/Out", "2012/Nov", "2012/Dez"]]

usaveis_2012["2012"] = usaveis_2012.sum(axis=1)

usaveis_2012 = usaveis_2012[["2012"]]

usaveis_2012.head()

# %%
usaveis_2013 = usaveis[["2013/Jan", "2013/Fev", "2013/Mar", "2013/Abr", "2013/Mai", "2013/Jun", "2013/Jul", "2013/Ago", "2013/Set", "2013/Out", "2013/Nov", "2013/Dez"]]

usaveis_2013["2013"] = usaveis_2013.sum(axis=1)

usaveis_2013 = usaveis_2013[["2013"]]

usaveis_2013.head()

# %%
usaveis_2013 = usaveis[["2013/Jan", "2013/Fev", "2013/Mar", "2013/Abr", "2013/Mai", "2013/Jun", "2013/Jul", "2013/Ago", "2013/Set", "2013/Out", "2013/Nov", "2013/Dez"]]

usaveis_2013["2013"] = usaveis_2013.sum(axis=1)

usaveis_2013 = usaveis_2013[["2013"]]

usaveis_2013.head()

# %%
usaveis_2014 = usaveis[["2014/Jan", "2014/Fev", "2014/Mar", "2014/Abr", "2014/Mai", "2014/Jun", "2014/Jul", "2014/Ago", "2014/Set", "2014/Out", "2014/Nov", "2014/Dez"]]

usaveis_2014["2014"] = usaveis_2014.sum(axis=1)

usaveis_2014 = usaveis_2014[["2014"]]

usaveis_2014.head()

# %%
usaveis_2015 = usaveis[["2015/Jan", "2015/Fev", "2015/Mar", "2015/Abr", "2015/Mai", "2015/Jun", "2015/Jul", "2015/Ago", "2015/Set", "2015/Out", "2015/Nov", "2015/Dez"]]

usaveis_2015["2015"] = usaveis_2015.sum(axis=1)

usaveis_2015 = usaveis_2015[["2015"]]

usaveis_2015.head()

# %%
usaveis_2016 = usaveis[["2016/Jan", "2016/Fev", "2016/Mar", "2016/Abr", "2016/Mai", "2016/Jun", "2016/Jul", "2016/Ago", "2016/Set", "2016/Out", "2016/Nov", "2016/Dez"]]

usaveis_2016["2016"] = usaveis_2016.sum(axis=1)

usaveis_2016 = usaveis_2016[["2016"]]

usaveis_2016.head()

# %%
usaveis_2017 = usaveis[["2017/Jan", "2017/Fev", "2017/Mar", "2017/Abr", "2017/Mai", "2017/Jun", "2017/Jul", "2017/Ago", "2017/Set", "2017/Out", "2017/Nov", "2017/Dez"]]

usaveis_2017["2017"] = usaveis_2017.sum(axis=1)

usaveis_2017 = usaveis_2017[["2017"]]

usaveis_2017.head()

# %%
usaveis_2018 = usaveis[["2018/Jan", "2018/Fev", "2018/Mar", "2018/Abr", "2018/Mai", "2018/Jun", "2018/Jul", "2018/Ago", "2018/Set", "2018/Out", "2018/Nov", "2018/Dez"]]

usaveis_2018["2018"] = usaveis_2018.sum(axis=1)

usaveis_2018 = usaveis_2018[["2018"]]

usaveis_2018.head()

# %%
usaveis_2019 = usaveis[["2019/Jan", "2019/Fev", "2019/Mar", "2019/Abr", "2019/Mai", "2019/Jun", "2019/Jul", "2019/Ago", "2019/Set", "2019/Out", "2019/Nov", "2019/Dez"]]

usaveis_2019["2019"] = usaveis_2019.sum(axis=1)

usaveis_2019 = usaveis_2019[["2019"]]

usaveis_2019.head()

# %%
usaveis_2020 = usaveis[["2020/Jan", "2020/Fev", "2020/Mar", "2020/Abr", "2020/Mai", "2020/Jun", "2020/Jul", "2020/Ago", "2020/Set", "2020/Out", "2020/Nov", "2020/Dez"]]

usaveis_2020["2020"] = usaveis_2020.sum(axis=1)

usaveis_2020 = usaveis_2020[["2020"]]

usaveis_2020.head()

# %%
import pandas as pd

hospital = pd.concat([usaveis_2008, usaveis_2009, usaveis_2010, usaveis_2011, usaveis_2012, usaveis_2013, usaveis_2014, usaveis_2015, usaveis_2016, usaveis_2017, usaveis_2018, usaveis_2019, usaveis_2020], axis = 1)

hospital

# %%
import matplotlib.pyplot as plt


ax = hospital.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '52 Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %%
import matplotlib.pyplot as plt


ax = dengue.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '52 Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Notificação dos casos de dengue')
plt.title('Notificação dos casos de dengue', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# Os dados relacionados a dengue encontrados no DATASUS são anuais, por tanto, não deu para observar a sazonalidade.

# %% [markdown]
# #Desafio 7: Adicionar mais um estado novamente e tire suas conclusões sobre estados comparando com os demais. Tire suas conclusões e compartilhe.

# %%
import matplotlib.pyplot as plt


ax = hospital.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '13 Amazonas']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %%
import matplotlib.pyplot as plt


ax = dengue.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '13 Amazonas']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Notificação dos casos de dengue')
plt.title('Notificação dos casos de dengue', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# # **#AULA 4**
#
# #Desafio 1: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações
#
# #Desafio 2: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord

# %%
ordenado_por_total = ordenado_por_total / 1000000

ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150]


ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (10,6))
plt.ylim(0, 350)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (10,6))
plt.ylim(100, 350)

# %%
ordenado_por_total[ordenado_por_total.columns[-80:]].head(3).T.plot(figsize = (10,6))
plt.ylim(100, 350)

# %%
ordenado_por_total[meses_filtrados].head(5).T.plot(figsize = (20,6))
plt.ylim(0, 350)

# %% [markdown]
# # **#AULA 5**
#
# #Desafio 01: Buscar documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.
#
# #Desafio 02: Fazer um gráfico e uma tabela do gasto dos outros estados em função do seu estado. ou qualquer outro de interesse.
#
# #Desafio 03: Fazer o cálculo proporcional a população de seu estado e mais um a sua escolha.
#
# #Desafio 04: Faça uma análise dos dados analisados, levante hipóteses e compartilhe no Discord.
#
# #Desafio 05: Reproduza as análises feitas em aulas, refletindo e levantando hipóteses.
#
# # Super desafio: Escolha outro valor fora Valor aprovado no TABNET e explore estes dados. Esse será nosso projeto do módulo, mais detalhes no Desafio do módulo 1 na página do bootcamp.

# %%
mes_mais_recente = ordenado_por_total.columns[-1]

mes_mais_recente

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()

# %%
gastos_do_mais_recente.plot()

# %%
gastos_do_mais_recente.plot(kind = 'pie')

# %% [markdown]
# Horrores da pizza:
#
# - Legenda está horrível;
# - Número de fatias está inacreditável;
#
#
# Vantagens:
#
# - O gráfico veio ordenado

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind = 'pie')

# %% [markdown]
# Horrores da pizza:
#
# - Legenda está horrível;
# - Número de fatias está inacreditável;
# - Não dá para saber a ordem
# - Cores repetidas
# - Muito ruim para definir ordem
# - Pior para comparar

# %%
#visualização simples para valor absoluto

gastos_do_mais_recente

# %%
gastos_do_mais_recente/gastos_do_mais_recente.loc["Rio de Janeiro"]

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["Rio de Janeiro"]).head(5)

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)

(gastos_do_mais_recente.plot(kind = 'bar'))

# %% [markdown]
# Desafio 01: Buscar documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.

# %% [markdown]
# ### **#MÓDULO 2**

# %% [markdown]
# # **#AULA 1**
#
# #Desafio 01: Entre nos dados do wikipedia e Leis a Base de dados direto do Wikipedia.
#
# #Desafio 02: Neste desafio temos uma série de passos:
#
#
# *   Padronizar os nomes das colunas
# *   Transformar os dados nos tipos corretos
# *   Transformar a UF em index
#
# #Desafio 03: Buscar na documentação alguns métodos envolvendo strings
#
# #Desafio 04: Desenvolver uma função para a limpeza e tratamento dos dados, retornando duas tabelas "população" e "unida".

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)

(gastos_do_mais_recente.plot(kind = 'bar'))

# %%
gastos_proporcionais = (gastos_do_mais_recente / gastos_do_mais_recente.sum())*100
gastos_proporcionais.plot(kind = 'bar')

# %%
ibge_estimativa = pd.read_excel("https://github.com/liliansampaio/Producao_hospitalar_Brasil/raw/main/Dados/POP2020_20210331.xls")
ibge_estimativa.head()

# %%
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

#fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
from io import StringIO


dados_da_populacao_io = StringIO(dados_da_populacao)

populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao = populacao.dropna()
populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa"]
populacao = populacao[["populacao", "uf"]].set_index("uf")
display(populacao.head())
display(populacao.info())

# %%
populacao.index.str[:3]

# %%
gastos_do_mais_recente.head()

# %%
display(gastos_do_mais_recente.head())
display(populacao.head())

# %%
populacao.join(gastos_do_mais_recente)

# %%
populacao.index[0].strip()

# %%
populacao.index = populacao.index.str.strip()
populacao.head()

# %%
for estado in gastos_do_mais_recente.index:

  #print(f"{estado} {estado} => {estado}")

  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)

populacao.index

# %%
gastos_e_populacao_recente = populacao.join(gastos_do_mais_recente)
gastos_e_populacao_recente.head()

# %%
def insere_gastos_e_gasto_por_habitante_para(todos_os_gastos: pd.DataFrame, dados: pd.DataFrame, mes: str):
  gastos_do_mes = todos_os_gastos[mes]
  dados[f"gastos_{mes}"] = gastos_do_mes * 1000000
  dados[f"gasto_por_habitante_{mes}"] = dados[f"gastos_{mes}"] / dados["populacao"]

# %%
ordenado_por_total["2021/Mar"]

# %%
#Terrível

insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2021/Mar")
gastos_e_populacao_recente[["gastos_2021/Mar", "populacao"]].plot()

# %%
gastos_e_populacao_recente.head()

# %%
gastos_e_populacao_recente.loc[["Rio Grande do Sul", "São Paulo"]]

# %%
gastos_e_populacao_recente.head()

# %%
gastos_e_populacao_recente["gasto_por_habitante_2021/Mar"].plot(kind = 'bar')

# %%
import seaborn as sns

plt.figure(figsize=(7,7))

sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2021/Mar")

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2021/Mar")
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2021/Fev")
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2021/Jan")

gastos_e_populacao_recente.head()

# %% [markdown]
# ---

# %%
import seaborn as sns


plt.figure(figsize=(7,7))

sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2021/Mar")
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2021/Fev")
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2021/Jan")

# %%
plt.figure(figsize=(7,7))

sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2021/Mar")
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2021/Fev")
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2021/Jan")

# %%
ordenado_por_total.head()

# %%
sns.scatterplot(x=ordenado_por_total.columns, y=ordenado_por_total.loc["São Paulo"])

# %%
mensal = ordenado_por_total.T
mensal.head()

# %%
sns.scatterplot(data=mensal, x=mensal.index, y="São Paulo")

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y="São Paulo")
plt.xticks(rotation=45)
plt.ylim(0, 400)
ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=11))
plt.grid(True, linestyle="dotted")
plt.show()

# %% [markdown]
# #Desafio: Plote o gráfico com seu estado.

# %%
sns.scatterplot(data=mensal, x=mensal.index, y="Rio de Janeiro")

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=mensal, x=mensal.index, y="Rio de Janeiro")

# %% [markdown]
# #Desafio 01: Fazer o scatter plot feito em aula para o seu estado, leia um pouco da documentação sobre este gráfico e teste alguns parâmetros.
#
# #Desafio 02: Formatar o eixo y colocando a escala em milhões usando o StrMethodFormatter, colocar título e colocar título nos dois eixos. E alterar fonte (tamanho) dos títulos.

# %% [markdown]
# #Desafio 01: Fazer o scatter plot feito em aula para o seu estado, leia um pouco da documentação sobre este gráfico e teste alguns parâmetros.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20,12))

ax.scatter(data= mensal, x=mensal.index, y="Rio de Janeiro")

plt.xticks(rotation=45)
plt.ylim(0, 180)

ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=11))

ax.set_xlabel('Mês', fontsize=(15))
ax.set_ylabel('Valor total por atendimento (R$)', fontsize=(15))
ax.set_title('Valor total por procedimentos hospitalares do SUS no Rio de Janeiro', fontsize=(20))


ax.grid(True)


plt.show()

# %% [markdown]
# #Desafio 02: Formatar o eixo y colocando a escala em milhões usando o StrMethodFormatter, colocar título e colocar título nos dois eixos. E alterar fonte (tamanho) dos títulos.

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import numpy as np

def millions(x, pos):
  return '%d' % (x * 1e+6)

formatter = FuncFormatter(millions)


fig, ax = plt.subplots(figsize=(20,12))

ax.scatter(data= mensal, x=mensal.index, y="São Paulo")


plt.xticks(rotation=45)
plt.ylim(0, 400)


ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=11))
ax.yaxis.set_major_formatter(formatter)


ax.set_xlabel('Mês', fontsize=(15))
ax.set_ylabel('Valor total por atendimento (R$)', fontsize=(15))
ax.set_title('Valor total por procedimentos hospitalares do SUS em São Paulo', fontsize=(20))


ax.grid(True)

plt.show()
